# %% [markdown]
# # Using VGG16 model, Adam optimisation tool, Learning rate = 0.01, batch size = 32, epoch = 50, then 100 (divided into 2 phases)

# %%
# Install TensorFlow if not already installed
try:
    import tensorflow as tf
except ImportError:
    # !pip install tensorflow
    import tensorflow as tf

import os
import zipfile
import matplotlib.pyplot as plt
import numpy as np
# import tensorflow as tf # This line is no longer needed here as it's handled above
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. Extract Dataset
# Path where your zip file is located in Drive
# Correcting ZIP_PATH to assume the dataset is in Google Drive's root folder
ZIP_PATH = '/content/dataset.zip'
# Local folder in Colab (faster for training than reading directly from Drive)
EXTRACT_PATH = '/content/lung_cancer_data'

if not os.path.exists(EXTRACT_PATH):
    with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
        zip_ref.extractall(EXTRACT_PATH)
    print(f"Extraction complete to {EXTRACT_PATH}")

# 3. Path Configuration
# After extraction, verify if there is a subfolder inside.
# If 'benign', 'malignant', 'normal' are inside a folder named 'Data',
# update this to: DATASET_PATH = os.path.join(EXTRACT_PATH, 'Data')

# Dynamically find the actual data directory if it's nested
DATASET_PATH = EXTRACT_PATH
subdirs = [d for d in os.listdir(EXTRACT_PATH) if os.path.isdir(os.path.join(EXTRACT_PATH, d))]

# Check if there's a single subdirectory that might contain the actual dataset
if len(subdirs) == 1:
    DATASET_PATH = os.path.join(EXTRACT_PATH, subdirs[0])
    print(f"Detected a single subdirectory '{subdirs[0]}'. Setting DATASET_PATH to: {DATASET_PATH}")
elif len(subdirs) > 1 and 'Data' in subdirs: # Specific check if 'Data' exists among multiple
    DATASET_PATH = os.path.join(EXTRACT_PATH, 'Data')
    print(f"Detected 'Data' subdirectory. Setting DATASET_PATH to: {DATASET_PATH}")
else:
    print(f"No single subdirectory or 'Data' subdirectory detected. Using EXTRACT_PATH as DATASET_PATH: {DATASET_PATH}")

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

# Define the actual class names based on the dataset structure
# Assuming 'benign', 'malignant', 'normal' are the intended classes
# Correcting CLASS_NAMES to match the actual folder names in the dataset
CLASS_NAMES = ['Bengin cases', 'Malignant cases', 'Normal cases']

# 4. Data Augmentation and Generators
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    shear_range=0.2,
    horizontal_flip=True,
    validation_split=0.2 # 80/20 Train-Test Split
)

train_generator = train_datagen.flow_from_directory(
    DATASET_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='training',
    classes=CLASS_NAMES # Specify actual class names
)

test_generator = train_datagen.flow_from_directory(
    DATASET_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    subset='validation',
    shuffle=False,
    classes=CLASS_NAMES # Specify actual class names
)

# 5. Model Architecture (VGG16 Transfer Learning)
#
def build_model():
    base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    base_model.trainable = False # Freeze layers for Phase 1

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.3)(x)
    # The number of output classes should match len(CLASS_NAMES)
    predictions = Dense(len(CLASS_NAMES), activation='softmax')(x)

    return Model(inputs=base_model.input, outputs=predictions), base_model

model, base_model = build_model()

# 6. Callbacks for Optimization
callbacks = [
    EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1),
    ModelCheckpoint('best_lung_model.h5', monitor='val_accuracy', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6, verbose=1)
]

# 7. Phase 1: Training the Head
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

print("Starting Phase 1: Training custom classification head...")
history = model.fit(train_generator, validation_data=test_generator, epochs=100, callbacks=callbacks)

# 8. Phase 2: Gradual Unfreezing (Fine-Tuning)
# Unfreeze the last block of VGG16 (block5)
for layer in base_model.layers[-4:]:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=1e-5), # Low learning rate for fine-tuning
              loss='categorical_crossentropy',
              metrics=['accuracy'])

print("Starting Phase 2: Fine-tuning VGG16 layers...")
history_finetune = model.fit(train_generator, validation_data=test_generator, epochs=100, callbacks=callbacks)

# 9. Performance Visualization
def plot_metrics(h1, h2):
    acc = h1.history['accuracy'] + h2.history['accuracy']
    val_acc = h1.history['val_accuracy'] + h2.history['val_accuracy']
    plt.plot(acc, label='Train Acc')
    plt.plot(val_acc, label='Val Acc')
    plt.legend()
    plt.title('Accuracy Improvement')
    plt.show()

plot_metrics(history, history_finetune)

# 10. Final Evaluation
Y_pred = model.predict(test_generator)
y_pred = np.argmax(Y_pred, axis=1)

print('Confusion Matrix')
cm = confusion_matrix(test_generator.classes, y_pred)
sns.heatmap(cm, annot=True, fmt='d', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.show()

print('Classification Report')
print(classification_report(test_generator.classes, y_pred, target_names=list(test_generator.class_indices.keys())))
# Out:
# Mounted at /content/drive
# Extraction complete to /content/lung_cancer_data
# No single subdirectory or 'Data' subdirectory detected. Using EXTRACT_PATH as DATASET_PATH: /content/lung_cancer_data
# Found 878 images belonging to 3 classes.
# Found 219 images belonging to 3 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Starting Phase 1: Training custom classification head...
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 866ms/step - accuracy: 0.6834 - loss: 0.7702
# Epoch 1: val_accuracy improved from None to 0.51142, saving model to best_lung_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to best_lung_model.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.7415 - loss: 0.6533 - val_accuracy: 0.5114 - val_loss: 1.2202 - learning_rate: 0.0010
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 553ms/step - accuracy: 0.8131 - loss: 0.4194
# Epoch 2: val_accuracy did not improve from 0.51142
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 746ms/step - accuracy: 0.8223 - loss: 0.3886 - val_accuracy: 0.5114 - val_loss: 1.1162 - learning_rate: 0.0010
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - accuracy: 0.8796 - loss: 0.3083
# Epoch 3: val_accuracy improved from 0.51142 to 0.53425, saving model to best_lung_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: finished saving model to best_lung_model.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 693ms/step - accuracy: 0.8907 - loss: 0.2939 - val_accuracy: 0.5342 - val_loss: 0.8924 - learning_rate: 0.0010
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - accuracy: 0.9087 - loss: 0.2276
# Epoch 4: val_accuracy improved from 0.53425 to 0.59817, saving model to best_lung_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 4: finished saving model to best_lung_model.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 693ms/step - accuracy: 0.9066 - loss: 0.2330 - val_accuracy: 0.5982 - val_loss: 0.7691 - learning_rate: 0.0010
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 553ms/step - accuracy: 0.9171 - loss: 0.1982
# Epoch 5: val_accuracy improved from 0.59817 to 0.63470, saving model to best_lung_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 5: finished saving model to best_lung_model.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 737ms/step - accuracy: 0.9112 - loss: 0.2214 - val_accuracy: 0.6347 - val_loss: 0.6999 - learning_rate: 0.0010
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.9216 - loss: 0.2010
# Epoch 6: val_accuracy improved from 0.63470 to 0.65753, saving model to best_lung_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 6: finished saving model to best_lung_model.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 700ms/step - accuracy: 0.9146 - loss: 0.2082 - val_accuracy: 0.6575 - val_loss: 0.7006 - learning_rate: 0.0010
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.9187 - loss: 0.1811
# Epoch 7: val_accuracy improved from 0.65753 to 0.66210, saving model to best_lung_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: finished saving model to best_lung_model.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 690ms/step - accuracy: 0.9305 - loss: 0.1710 - val_accuracy: 0.6621 - val_loss: 0.6637 - learning_rate: 0.0010
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - accuracy: 0.9537 - loss: 0.1577
# Epoch 8: val_accuracy improved from 0.66210 to 0.71233, saving model to best_lung_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 8: finished saving model to best_lung_model.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 762ms/step - accuracy: 0.9317 - loss: 0.1961 - val_accuracy: 0.7123 - val_loss: 0.6381 - learning_rate: 0.0010
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - accuracy: 0.9235 - loss: 0.1941
# Epoch 9: val_accuracy improved from 0.71233 to 0.74429, saving model to best_lung_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 9: finished saving model to best_lung_model.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 702ms/step - accuracy: 0.9226 - loss: 0.1913 - val_accuracy: 0.7443 - val_loss: 0.6067 - learning_rate: 0.0010
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 553ms/step - accuracy: 0.9258 - loss: 0.1536
# Epoch 10: val_accuracy did not improve from 0.74429
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 686ms/step - accuracy: 0.9294 - loss: 0.1524 - val_accuracy: 0.6849 - val_loss: 0.7127 - learning_rate: 0.0010
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - accuracy: 0.9430 - loss: 0.1426
# Epoch 11: val_accuracy did not improve from 0.74429
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 751ms/step - accuracy: 0.9317 - loss: 0.1803 - val_accuracy: 0.7352 - val_loss: 0.6502 - learning_rate: 0.0010
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - accuracy: 0.9367 - loss: 0.1554
# Epoch 12: val_accuracy did not improve from 0.74429
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 687ms/step - accuracy: 0.9487 - loss: 0.1365 - val_accuracy: 0.7260 - val_loss: 0.7224 - learning_rate: 0.0010
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.9479 - loss: 0.1462
# Epoch 13: val_accuracy did not improve from 0.74429
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 680ms/step - accuracy: 0.9499 - loss: 0.1403 - val_accuracy: 0.7078 - val_loss: 0.8494 - learning_rate: 0.0010
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.9524 - loss: 0.1415
# Epoch 14: val_accuracy did not improve from 0.74429
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 751ms/step - accuracy: 0.9533 - loss: 0.1384 - val_accuracy: 0.6941 - val_loss: 0.7551 - learning_rate: 0.0010
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.9588 - loss: 0.0972
# Epoch 15: val_accuracy improved from 0.74429 to 0.75799, saving model to best_lung_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 15: finished saving model to best_lung_model.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 695ms/step - accuracy: 0.9567 - loss: 0.1124 - val_accuracy: 0.7580 - val_loss: 0.7864 - learning_rate: 2.0000e-04
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.9594 - loss: 0.1121
# Epoch 16: val_accuracy did not improve from 0.75799
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 683ms/step - accuracy: 0.9556 - loss: 0.1171 - val_accuracy: 0.7306 - val_loss: 0.8625 - learning_rate: 2.0000e-04
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - accuracy: 0.9552 - loss: 0.1063
# Epoch 17: val_accuracy did not improve from 0.75799
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 768ms/step - accuracy: 0.9590 - loss: 0.1132 - val_accuracy: 0.7260 - val_loss: 0.9531 - learning_rate: 2.0000e-04
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 0.9629 - loss: 0.1125
# Epoch 18: val_accuracy did not improve from 0.75799
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 715ms/step - accuracy: 0.9681 - loss: 0.0977 - val_accuracy: 0.7260 - val_loss: 0.9885 - learning_rate: 2.0000e-04
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9693 - loss: 0.0893
# Epoch 19: val_accuracy did not improve from 0.75799
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 687ms/step - accuracy: 0.9636 - loss: 0.1001 - val_accuracy: 0.7534 - val_loss: 1.0130 - learning_rate: 2.0000e-04
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Starting Phase 2: Fine-tuning VGG16 layers...
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 672ms/step - accuracy: 0.9416 - loss: 0.1480
# Epoch 1: val_accuracy improved from 0.75799 to 0.78082, saving model to best_lung_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to best_lung_model.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 35s 977ms/step - accuracy: 0.9544 - loss: 0.1307 - val_accuracy: 0.7808 - val_loss: 0.6224 - learning_rate: 1.0000e-05
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - accuracy: 0.9385 - loss: 0.1297
# Epoch 2: val_accuracy did not improve from 0.78082
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 702ms/step - accuracy: 0.9476 - loss: 0.1163 - val_accuracy: 0.7580 - val_loss: 0.6665 - learning_rate: 1.0000e-05
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 583ms/step - accuracy: 0.9414 - loss: 0.1438
# Epoch 3: val_accuracy did not improve from 0.78082
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 747ms/step - accuracy: 0.9465 - loss: 0.1404 - val_accuracy: 0.7443 - val_loss: 0.7258 - learning_rate: 1.0000e-05
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - accuracy: 0.9606 - loss: 0.1049
# Epoch 4: val_accuracy did not improve from 0.78082
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 39s 688ms/step - accuracy: 0.9544 - loss: 0.1142 - val_accuracy: 0.7169 - val_loss: 0.6613 - learning_rate: 1.0000e-05
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - accuracy: 0.9720 - loss: 0.0846
# Epoch 5: val_accuracy did not improve from 0.78082
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 753ms/step - accuracy: 0.9613 - loss: 0.1049 - val_accuracy: 0.7717 - val_loss: 0.6985 - learning_rate: 1.0000e-05
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.9525 - loss: 0.1258
# Epoch 6: val_accuracy improved from 0.78082 to 0.79452, saving model to best_lung_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 6: finished saving model to best_lung_model.h5
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 703ms/step - accuracy: 0.9613 - loss: 0.1051 - val_accuracy: 0.7945 - val_loss: 0.7309 - learning_rate: 2.0000e-06
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - accuracy: 0.9692 - loss: 0.0781
# Epoch 7: val_accuracy did not improve from 0.79452
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 20s 723ms/step - accuracy: 0.9636 - loss: 0.0933 - val_accuracy: 0.7671 - val_loss: 0.8584 - learning_rate: 2.0000e-06
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.9767 - loss: 0.0869
# Epoch 8: val_accuracy did not improve from 0.79452
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 736ms/step - accuracy: 0.9715 - loss: 0.0858 - val_accuracy: 0.7717 - val_loss: 0.8136 - learning_rate: 2.0000e-06
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - accuracy: 0.9703 - loss: 0.0693
# Epoch 9: val_accuracy did not improve from 0.79452
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 19s 697ms/step - accuracy: 0.9704 - loss: 0.0763 - val_accuracy: 0.7215 - val_loss: 0.9763 - learning_rate: 2.0000e-06
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.9683 - loss: 0.0817
# Epoch 10: val_accuracy did not improve from 0.79452
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1e-06.
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 21s 758ms/step - accuracy: 0.9658 - loss: 0.0825 - val_accuracy: 0.7489 - val_loss: 0.8892 - learning_rate: 2.0000e-06
# Epoch 10: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 534ms/step
# Confusion Matrix
# Classification Report
#                  precision    recall  f1-score   support
#
#    Bengin cases       0.23      0.12      0.16        24
# Malignant cases       0.91      0.90      0.91       112
#    Normal cases       0.69      0.80      0.74        83
#
#        accuracy                           0.78       219
#       macro avg       0.61      0.61      0.60       219
#    weighted avg       0.75      0.78      0.76       219
